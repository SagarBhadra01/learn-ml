# %%
# %pip install plotly
# %pip install cufflinks
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import cufflinks as cf
import plotly.offline as py
import plotly.express as px
from plotly.offline import iplot

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import numpy as np
import plotly.express as px

# Assuming tips is a pandas DataFrame
# Replace the problematic iplot() with a more reliable plotly express function
fig = px.line(tips, y='total_bill')
fig.show()

# Alternatively, if you want to stick with iplot, fix the color issue:
# import cufflinks as cf
# cf.go_offline()
# tips['total_bill'].iplot(colors=['rgba(255, 153, 51, 1.0)'])

# %%
tips.groupby('day')['tip'].mean().iplot(kind= 'bar')
# Out:
# C:\Users\SAGAR BHADRA\AppData\Local\Temp\ipykernel_3364\4285252914.py:1: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 tips.groupby('day')['tip'].mean().iplot(kind= 'bar')
#
# ...

# %% [markdown]
# # Assistant
# This error is related to the color formatting in the `iplot` function from the Plotly library. The error occurs because there's an issue with the color string format - specifically, it's trying to use a NumPy float inside a string.
#
# The error message indicates that the color value `'rgba(255, 153, 51, np.float64(1.0))'` is invalid because it contains `np.float64(1.0)` directly in the string instead of converting it to a regular number.
#
# Would you like me to provide the corrected code?
